# %%
data <- read.csv("../Input_for_Models/Input_MANCOVA/chols_mechs_confs.csv")

# %%
colnames(data)
# Out:
#  [1] "X"
#  [2] "Campestanol.µg.dl"
#  [3] "Campesterol.mg.dl"
#  [4] "Sitostanol.µg.dl"
#  [5] "Sitosterol.mg.dl"
#  [6] "Stigmasterol.µg.dl"
#  [7] "MAPK.subgraph"
#  [8] "Calcium.dependent.signal.transduction"
#  [9] "Synuclein.subgraph"
# [10] "Notch.signaling.subgraph"
# [11] "Ubiquitin.subgraph"
# [12] "Chaperone.subgraph"
# [13] "Caspase.subgraph"
# [14] "Reactive.oxygen.species.subgraph"
# [15] "Mitochondrial.subgraph"
# [16] "Mitophagy.subgraph"
# [17] "LRRK2.subgraph"
# [18] "CRH.subgraph"
# [19] "Regulation.of.cytoskeleton.subgraph"
# [20] "Phosphatidylinositol.3.subgraph"
# [21] "Apoptosis.signaling.subgraph"
# [22] "Autophagy.signaling.subgraph"
# [23] "Wnt.signaling.subgraph"
# [24] "GSK3.subgraph"
# [25] "Tau.protein.subgraph"
# [26] "ATP13A2.subgraph"
# [27] "Endoplasmic.reticulum.Golgi.protein.export"
# [28] "Interleukin.signaling.subgraph"
# [29] "Dopaminergic.subgraph"
# [30] "Cell.cycle.subgraph"
# [31] "Vitamin.subgraph"
# [32] "Transcription.subgraph"
# ...
